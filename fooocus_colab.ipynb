# %% [markdown]
# <a href="https://colab.research.google.com/github/sitthichai12/fooocus_colab_ngrokweb/blob/main/fooocus_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. ติดตั้งไลบรารี
# !pip install pygit2==1.19.3 pyngrok

# 2. ตั้งค่า Ngrok Authtoken
from pyngrok import ngrok
import time

NGROK_TOKEN = "นำ_AUTHTOKEN_ของคุณมาวางที่นี่"
ngrok.set_auth_token(NGROK_TOKEN)
ngrok.kill() # ล้าง connection เก่าที่ค้างอยู่

# 3. ดาวน์โหลด Fooocus
# %cd /content
# !git clone https://huggingface.co/jamester12/Fooocus2.5.5TEST
# %cd /content/Fooocus2.5.5TEST

# %%
# 4. สั่งเปิด Ngrok (ใช้ Port 7865 ซึ่งเป็น Port หลักของ Fooocus)
public_url = ngrok.connect(7865)
print(f"\n==========================================")
print(f"ลิงก์ Ngrok ของคุณ: {public_url}")
print(f"==========================================\n")

# 5. รัน Fooocus
# !python entry_with_update.py --always-high-vram --port 7865

# %%
# checkpoints
# !wget -O /content/Fooocus2.5.5TEST/models/checkpoints/-------------.safetensors "---------------------------------------&token=5a6e3c5fb11f6fcdc3deef1eb0863941"

# %%
# LORA
# !wget -O /content/Fooocus2.5.5TEST/models/lora/--------------.safetensors "---------------------------------------&token=5a6e3c5fb11f6fcdc3deef1eb0863941"
